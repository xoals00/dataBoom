# %%
#-*- coding:utf-8 -*-
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import minmax_scale
import requests
import pymysql
import random
from tqdm import tqdm
import time
import math
import joblib
import pickle

tierList = ['IRON','BRONZE','SILVER','GOLD','PLATINUM','EMERALD','DIAMOND']
# tierList = ['DIAMOND']
teamPositionList = ['TOP', 'JUNGLE', 'MIDDLE','BOTTOM','UTILITY']
championNameList = []

#########################
def connect_mysql(db='mydb'):
    conn = pymysql.connect(host='svc.sel4.cloudtype.app', port=32509,
                        user='root', password='1234',
                        db=db, charset='utf8')
    return conn

queueId = str(420) #큐아이디
# limit_value = str(200) # 리미트값
############################

conn = connect_mysql()
cursor = conn.cursor()
query = "SELECT champion_name FROM champListT;" #총 챔피언 리스트
cursor.execute(query)
result = cursor.fetchall()
data = list(result)
for i in range(len(data)):

    championNameList.append(data[i][0])           
for tier in tqdm(tierList):
    for teamPosition in teamPositionList:
        for championName in championNameList:
    
            query = "select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = '" +tier+ "' and teamPosition = '" +teamPosition+ "' and championName = '" +championName+ "' and queueId = '" +queueId+ "'"
            print(query)
            cursor.execute(query)

            result = cursor.fetchall()
            data = list(result)
            # print(len(data))
            joblib.dump(data, './'+queueId+'_'+tier+'_'+championName+'.pkl')


        # for championName1 in championNameList:
        #     testList = []
        #     for i in range(len(data)): 
        #         win,deaths,gameDuration,kda,totalDamageDealtToChampions,goldEarned,championName = data[i]
        #         # print(championName)
        #         if championName == championName1:
        #             testList.append(data[i])

            # if len(testList) > 100 : 
            #     testList = testList[:100] #500개로 줄임 이유 : 과적합
            # elif len(testList) < 25 : 
            #     testList = []
          
         
            # if  len(testList) > 50 :
            #     print(len(testList))
            #     lose_gameDuration_List = []
            #     lose_kda_List = []
            #     lose_Mean_totalDamageDealtToChampions = []
            #     lose_Mean_goldEarned = []
            #     # lose_Mean_deaths = []


            #     win_gameDuration_List = []
            #     win_kda_List = []
            #     win_Mean_totalDamageDealtToChampions = []
            #     win_Mean_goldEarned = []
            #     # win_Mean_deaths = []

            #     for e in testList:
            #         win,deaths,gameDuration,kda,totalDamageDealtToChampions,goldEarned,championName = e
            #         if deaths == 0:
            #             deaths = 1
            #         if win == 'False':
            #             lose_gameDuration_List.append(gameDuration)
            #             lose_kda_List.append(kda)
            #             lose_Mean_totalDamageDealtToChampions.append(int(totalDamageDealtToChampions/gameDuration/deaths))
            #             lose_Mean_goldEarned.append(int(goldEarned/gameDuration/deaths))
            #         elif win == 'True' :
            #             win_gameDuration_List.append(gameDuration)
            #             win_kda_List.append(kda)
            #             win_Mean_totalDamageDealtToChampions.append(int(totalDamageDealtToChampions/gameDuration/deaths))
            #             win_Mean_goldEarned.append(int(goldEarned/gameDuration/deaths))


            #     w = len(win_Mean_goldEarned)
            #     l = len(lose_Mean_goldEarned)

            #     if w > l : 
            #         win_Mean_goldEarned = win_Mean_goldEarned[:l]
            #         win_Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions[:l]
            #         win_kda_List = win_kda_List[:l]
            #         win_gameDuration_List = win_gameDuration_List[:l]
            #     else : 
            #         lose_Mean_goldEarned = lose_Mean_goldEarned[:w]
            #         lose_Mean_totalDamageDealtToChampions = lose_Mean_totalDamageDealtToChampions[:w]
            #         lose_kda_List = lose_kda_List[:w]
            #         lose_gameDuration_List = lose_gameDuration_List[:w]
            #     if (w + l) >100 :
            #         win_Mean_goldEarned = win_Mean_goldEarned[:50]
            #         win_Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions[:50]
            #         win_kda_List = win_kda_List[:50]
            #         win_gameDuration_List = win_gameDuration_List[:50]
   
            #         lose_Mean_goldEarned = lose_Mean_goldEarned[:50]
            #         lose_Mean_totalDamageDealtToChampions = lose_Mean_totalDamageDealtToChampions[:50]
            #         lose_kda_List = lose_kda_List[:50]
            #         lose_gameDuration_List = lose_gameDuration_List[:50]
                
            #     allkda = win_kda_List+lose_kda_List
                
            #     Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions + lose_Mean_totalDamageDealtToChampions
            #     Mean_goldEarned = win_Mean_goldEarned + lose_Mean_goldEarned

            #     tier_data=[[t,g,k]for t,g,k in zip(Mean_totalDamageDealtToChampions,Mean_goldEarned,allkda)]

            #     tier_target=[1]*len(win_kda_List)+[0]*len(lose_kda_List)

            #     tierMap =  {'allkda' : allkda , 'Mean_totalDamageDealtToChampions':Mean_totalDamageDealtToChampions , 'Mean_goldEarned':Mean_goldEarned}

                #z-정규화
                # mean = np.mean(tier_data, axis=0)
                # std = np.std(tier_data, axis=0)
                # train_scaled = (tier_data - mean) / std

                # dataset = {'data' : train_scaled, 'target' : tier_target}

            # 입력 데이터와 타깃을 준비합니다.
                # X, y = dataset['data'], dataset['target']

                # K 최근접이웃 모델 객체를 만듭니다.
                # model = KNeighborsClassifier(n_neighbors=3)
                
            # K 최근접 이웃 모델에 입력 데이터와 타깃을 입력하고 학습시킨다.
                # model.fit(X,y)
                # 학습시킨 모델을 현재 경로에 knn_model.pkl 파일로 저장합니다.

            
conn.close()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Annie' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Olaf' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Galio' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'TwistedFate' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'XinZhao' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Urgot' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Leblanc' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Vladimir' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Fiddlesticks' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Kayle' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'MasterYi' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Alistar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Ryze' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Sion' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Sivir' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Soraka' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Teemo' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Tristana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Warwick' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Nunu' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'MissFortune' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Ashe' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Tryndamere' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Jax' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Morgana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Zilean' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Singed' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Evelynn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Twitch' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Karthus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Chogath' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Amumu' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Rammus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Anivia' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Shaco' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'DrMundo' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Sona' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Kassadin' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Irelia' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Janna' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Gangplank' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Corki' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Karma' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Taric' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Veigar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Trundle' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Swain' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Caitlyn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Blitzcrank' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Malphite' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Katarina' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Nocturne' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Maokai' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Renekton' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'JarvanIV' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Elise' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Orianna' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'MonkeyKing' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Brand' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'LeeSin' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Vayne' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Rumble' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Cassiopeia' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Skarner' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Heimerdinger' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Nasus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Nidalee' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Udyr' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Poppy' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Gragas' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Pantheon' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Ezreal' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Mordekaiser' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Yorick' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Akali' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Kennen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Garen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Leona' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Malzahar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Talon' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Riven' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'KogMaw' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Shen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Lux' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Xerath' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Shyvana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Ahri' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Graves' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Fizz' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Volibear' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Rengar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Varus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Nautilus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Viktor' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Sejuani' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Fiora' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Ziggs' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Lulu' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Draven' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Hecarim' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Khazix' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Darius' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Jayce' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Lissandra' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Diana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Quinn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Syndra' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'AurelionSol' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Kayn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Zoe' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Zyra' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Kaisa' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Seraphine' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Gnar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Zac' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Yasuo' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Velkoz' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Taliyah' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Camille' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Akshan' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Belveth' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Braum' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Jhin' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Kindred' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Zeri' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Jinx' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'TahmKench' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Briar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Viego' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Senna' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Lucian' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Zed' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Kled' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Ekko' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Qiyana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Vi' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Aatrox' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Nami' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Azir' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Yuumi' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Samira' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Thresh' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Illaoi' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'RekSai' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Ivern' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Kalista' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Bard' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Rakan' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Xayah' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Ornn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Sylas' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Neeko' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Aphelios' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Rell' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Pyke' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Vex' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Yone' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Sett' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Lillia' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Gwen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Renata' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Nilah' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'KSante' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Smolder' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Milio' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Hwei' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'TOP' and championName = 'Naafiri' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Annie' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Olaf' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Galio' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'TwistedFate' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'XinZhao' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Urgot' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Leblanc' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Vladimir' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Fiddlesticks' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Kayle' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'MasterYi' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Alistar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Ryze' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Sion' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Sivir' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Soraka' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Teemo' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Tristana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Warwick' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Nunu' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'MissFortune' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Ashe' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Tryndamere' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Jax' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Morgana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Zilean' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Singed' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Evelynn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Twitch' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Karthus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Chogath' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Amumu' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Rammus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Anivia' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Shaco' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'DrMundo' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Sona' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Kassadin' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Irelia' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Janna' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Gangplank' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Corki' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Karma' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Taric' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Veigar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Trundle' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Swain' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Caitlyn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Blitzcrank' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Malphite' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Katarina' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Nocturne' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Maokai' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Renekton' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'JarvanIV' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Elise' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Orianna' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'MonkeyKing' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Brand' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'LeeSin' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Vayne' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Rumble' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Cassiopeia' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Skarner' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Heimerdinger' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Nasus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Nidalee' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Udyr' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Poppy' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Gragas' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Pantheon' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Ezreal' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Mordekaiser' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Yorick' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Akali' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Kennen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Garen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Leona' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Malzahar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Talon' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Riven' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'KogMaw' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Shen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Lux' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Xerath' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Shyvana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Ahri' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Graves' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Fizz' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Volibear' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Rengar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Varus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Nautilus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Viktor' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Sejuani' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Fiora' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Ziggs' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Lulu' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Draven' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Hecarim' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Khazix' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Darius' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Jayce' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Lissandra' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Diana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Quinn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'Syndra' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'IRON' and teamPosition = 'JUNGLE' and championName = 'AurelionSol' and queueId = '420'
# ...
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Talon' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Riven' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'KogMaw' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Shen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Lux' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Xerath' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Shyvana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Ahri' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Graves' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Fizz' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Volibear' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Rengar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Varus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Nautilus' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Viktor' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Sejuani' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Fiora' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Ziggs' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Lulu' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Draven' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Hecarim' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Khazix' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Darius' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Jayce' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Lissandra' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Diana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Quinn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Syndra' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'AurelionSol' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Kayn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Zoe' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Zyra' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Kaisa' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Seraphine' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Gnar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Zac' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Yasuo' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Velkoz' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Taliyah' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Camille' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Akshan' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Belveth' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Braum' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Jhin' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Kindred' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Zeri' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Jinx' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'TahmKench' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Briar' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Viego' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Senna' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Lucian' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Zed' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Kled' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Ekko' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Qiyana' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Vi' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Aatrox' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Nami' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Azir' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Yuumi' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Samira' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Thresh' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Illaoi' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'RekSai' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Ivern' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Kalista' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Bard' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Rakan' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Xayah' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Ornn' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Sylas' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Neeko' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Aphelios' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Rell' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Pyke' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Vex' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Yone' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Sett' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Lillia' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Gwen' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Renata' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Nilah' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'KSante' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Smolder' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Milio' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Hwei' and queueId = '420'
# select win,gameDuration,kda,totalDamageDealtToChampions,goldEarned from riottvT where tier = 'DIAMOND' and teamPosition = 'UTILITY' and championName = 'Naafiri' and queueId = '420'
# 100%|██████████| 7/7 [6:19:56<00:00, 3256.61s/it]

# %%
#-*- coding:utf-8 -*-
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import minmax_scale
from tqdm import tqdm
import time
import math
import joblib
#빅데이터전용
import pickle 
from sklearn.datasets import fetch_openml

data = sys.argv[1:]
# key = data[0]
# tier = data[1]
# teamPosition = data[2]
# gameDuration = int(data[3])
# kda = float(data[4])
# totalDamageDealtToChampions = int(int(data[5])/gameDuration) 
# goldEarned = int(int(data[6])/gameDuration)
# championName = data[7]
# queueId = str(data[8])
matchId = 'kr'
key= '123'
tier = 'GOLD'
kda = 10
totalDamageDealtToChampions = 1500
goldEarned = 600
teamPosition = 'TOP'
championName = 'Rumble' #캐릭터
tier_my = [totalDamageDealtToChampions,goldEarned,kda]
mean = np.mean(tier_my, axis=0)
std = np.std(tier_my, axis=0)

new = (tier_my - mean) / std
 
str1 ='./420_'+tier+'_'+championName+'.pkl'
# str2 = './'+queueId+'_'+tier+'_'+teamPosition+ '_' + championName+'.pickle'
# with open(str2,'rb') as f:
#     loaded_model = pickle.load(f)
# str2 = './420_BRONZE_JUNGLE_LeeSin.pkl'	
data = joblib.load(str1)

   
lose_gameDuration_List = []
lose_kda_List = []
lose_Mean_totalDamageDealtToChampions = []
lose_Mean_goldEarned = []

win_gameDuration_List = []
win_kda_List = []
win_Mean_totalDamageDealtToChampions = []
win_Mean_goldEarned = []

for e in data:
    win,gameDuration,kda,totalDamageDealtToChampions,goldEarned = e
    if win == 'False':
        lose_gameDuration_List.append(gameDuration)
        lose_kda_List.append(kda)
        lose_Mean_totalDamageDealtToChampions.append(int(totalDamageDealtToChampions/gameDuration))
        lose_Mean_goldEarned.append(int(goldEarned/gameDuration))
    elif win == 'True' :
        win_gameDuration_List.append(gameDuration)
        win_kda_List.append(kda)
        win_Mean_totalDamageDealtToChampions.append(int(totalDamageDealtToChampions/gameDuration))
        win_Mean_goldEarned.append(int(goldEarned/gameDuration))
# print(win_gameDuration_List)

#######################################################################################################################################
if len(win_Mean_goldEarned) > len(lose_Mean_goldEarned) : 

    win_Mean_goldEarned = win_Mean_goldEarned[ : len(lose_Mean_goldEarned)]
    win_Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions[ : len(lose_Mean_totalDamageDealtToChampions)]

elif len(lose_Mean_goldEarned) > len(win_Mean_goldEarned) : 


    lose_Mean_goldEarned = lose_Mean_goldEarned[ : len(win_Mean_goldEarned)]
    lose_Mean_totalDamageDealtToChampions = lose_Mean_totalDamageDealtToChampions[ : len(win_Mean_totalDamageDealtToChampions)]

if  len(lose_Mean_goldEarned) > 50 :
    lose_Mean_goldEarned = lose_Mean_goldEarned[ : 50]
    win_Mean_goldEarned = win_Mean_goldEarned[ : 50]
    lose_Mean_totalDamageDealtToChampions = lose_Mean_totalDamageDealtToChampions[ : 50]
    win_Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions[ : 50]



try:
    allkda = win_kda_List+lose_kda_List
    Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions + lose_Mean_totalDamageDealtToChampions
    Mean_goldEarned = win_Mean_goldEarned + lose_Mean_goldEarned

    tier_data=[[t,g,k]for t,g,k in zip(Mean_totalDamageDealtToChampions,Mean_goldEarned,allkda)]

    #그래프
    plt.scatter(win_Mean_totalDamageDealtToChampions, win_Mean_goldEarned) 
    plt.scatter(lose_Mean_totalDamageDealtToChampions, lose_Mean_goldEarned)
    # plt.xlim((0, 2000))
    plt.title(championName)
    plt.xlabel('DAMAGE') 
    plt.ylabel('GOLD') 
    plt.show()


    tier_target=[1]*len(win_kda_List)+[0]*len(lose_kda_List)
    kn = KNeighborsClassifier(n_neighbors=3)

    kn.fit(tier_data,tier_target)
    a1 = kn.score(tier_data,tier_target)



    #z-정규화
    mean = np.mean(tier_data, axis=0)
    std = np.std(tier_data, axis=0)

    # print(mean, std)
    train_scaled = (tier_data - mean) / std

    # print(totalDamageDealtToChampions)
    # new = ([totalDamageDealtToChampions, goldEarned] - mean) / std
    new = (tier_my - mean) / std
    #그래프
    plt.scatter(train_scaled[:, 0], train_scaled[:, 1])
    plt.scatter(new[0], new[1], marker='^')
    plt.title(championName)
    plt.xlabel('length')
    plt.ylabel('weight')
    plt.show()

    kn.fit(train_scaled, tier_target)
    a1 = kn.score(train_scaled, tier_target) # 1.0
    trans={1:'승', 0:'패'}
    a = trans[kn.predict([new])[0]]

    if len(tier_target) < 10 : 

        data5 = {key:"데이터부족" , "정확도" : a1 , "총데이터길이"  :len(tier_target), '구간' : tier , '캐릭' : championName , "key":"데이터부족"}
    else :
        data5 = {key:a , "정확도" : a1 , "총데이터길이"  :len(tier_target), '구간' : tier , '캐릭' : championName, "key" : a}  
    json_string = json.dumps(data5)
    # print(a, a1)
    print(data5)
except Exception as e:
    data5 = {key:"에러" , "정확도" : 0 , "총데이터길이"  :0, '구간' : tier , '캐릭' : championName, "key" : "에러"}  
    json_string = json.dumps(data5)
    # print(a, a1)
    print(json_string)
# Out:
# {"123": "\uc5d0\ub7ec", "\uc815\ud655\ub3c4": 0, "\ucd1d\ub370\uc774\ud130\uae38\uc774": 0, "\uad6c\uac04": "GOLD", "\uce90\ub9ad": "Rumble", "key": "\uc5d0\ub7ec"}

# %%
#-*- coding:utf-8 -*-
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import minmax_scale
from tqdm import tqdm
import time
import math
import joblib
#빅데이터전용
import pickle 
from sklearn.datasets import fetch_openml

key= '123'
tier = 'GOLD'
kda = 10
totalDamageDealtToChampions = 1500
goldEarned = 600
teamPosition = 'TOP'
championName = 'Rumble' #캐릭터
tier_my = [totalDamageDealtToChampions,goldEarned]
mean = np.mean(tier_my, axis=0)
std = np.std(tier_my, axis=0)

new = (tier_my - mean) / std
 
str1 ='./420_'+tier+'_'+championName+'.pkl'
# str2 = './'+queueId+'_'+tier+'_'+teamPosition+ '_' + championName+'.pickle'
# with open(str2,'rb') as f:
#     loaded_model = pickle.load(f)
# str2 = './420_BRONZE_JUNGLE_LeeSin.pkl'	
data = joblib.load(str1)

   
lose_gameDuration_List = []
# lose_kda_List = []
lose_Mean_totalDamageDealtToChampions = []
lose_Mean_goldEarned = []

win_gameDuration_List = []
# win_kda_List = []
win_Mean_totalDamageDealtToChampions = []
win_Mean_goldEarned = []

for e in data:
    win,gameDuration,kda,totalDamageDealtToChampions,goldEarned = e
    if win == 'False':
        lose_gameDuration_List.append(gameDuration)
        # lose_kda_List.append(kda)
        lose_Mean_totalDamageDealtToChampions.append(int(totalDamageDealtToChampions/gameDuration*kda))
        lose_Mean_goldEarned.append(int(goldEarned/gameDuration*kda))
    elif win == 'True' :
        win_gameDuration_List.append(gameDuration)
        # win_kda_List.append(kda)
        win_Mean_totalDamageDealtToChampions.append(int(totalDamageDealtToChampions/gameDuration*kda))
        win_Mean_goldEarned.append(int(goldEarned/gameDuration*kda))
# print(win_gameDuration_List)

#######################################################################################################################################
if len(win_Mean_goldEarned) > len(lose_Mean_goldEarned) : 

    win_Mean_goldEarned = win_Mean_goldEarned[ : len(lose_Mean_goldEarned)]
    win_Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions[ : len(lose_Mean_totalDamageDealtToChampions)]

elif len(lose_Mean_goldEarned) > len(win_Mean_goldEarned) : 


    lose_Mean_goldEarned = lose_Mean_goldEarned[ : len(win_Mean_goldEarned)]
    lose_Mean_totalDamageDealtToChampions = lose_Mean_totalDamageDealtToChampions[ : len(win_Mean_totalDamageDealtToChampions)]

if  len(lose_Mean_goldEarned) > 50 :
    lose_Mean_goldEarned = lose_Mean_goldEarned[ : 50]
    win_Mean_goldEarned = win_Mean_goldEarned[ : 50]
    lose_Mean_totalDamageDealtToChampions = lose_Mean_totalDamageDealtToChampions[ : 50]
    win_Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions[ : 50]



try:

    Mean_totalDamageDealtToChampions = win_Mean_totalDamageDealtToChampions + lose_Mean_totalDamageDealtToChampions
    Mean_goldEarned = win_Mean_goldEarned + lose_Mean_goldEarned

    tier_data=[[t,g]for t,g in zip(Mean_totalDamageDealtToChampions,Mean_goldEarned)]

    #그래프
    # plt.scatter(win_Mean_totalDamageDealtToChampions, win_Mean_goldEarned) 
    # plt.scatter(lose_Mean_totalDamageDealtToChampions, lose_Mean_goldEarned)
    # # plt.xlim((0, 2000))
    # plt.title(championName)
    # plt.xlabel('DAMAGE') 
    # plt.ylabel('GOLD') 
    # plt.show()


    tier_target=[1]*len(win_Mean_goldEarned)+[0]*len(lose_Mean_goldEarned)
    kn = KNeighborsClassifier(n_neighbors=3)

    kn.fit(tier_data,tier_target)
    a1 = kn.score(tier_data,tier_target)



    #z-정규화
    mean = np.mean(tier_data, axis=0)
    std = np.std(tier_data, axis=0)

    # print(mean, std)
    train_scaled = (tier_data - mean) / std

    # print(totalDamageDealtToChampions)
    # new = ([totalDamageDealtToChampions, goldEarned] - mean) / std
    new = (tier_my - mean) / std
    #그래프
    # plt.scatter(train_scaled[:, 0], train_scaled[:, 1])
    # plt.scatter(new[0], new[1], marker='^')
    # plt.title(championName)
    # plt.xlabel('length')
    # plt.ylabel('weight')
    # plt.show()

    kn.fit(train_scaled, tier_target)
    a1 = kn.score(train_scaled, tier_target) # 1.0
    trans={1:'승', 0:'패'}
    a = trans[kn.predict([new])[0]]

    data5 = {'matchId': matchId , "accuracy" : a1 , "length"  :len(tier_target), 'tier' : tier , 'championName' : championName, "key" : a,  "rankingS" : int(new[0]+new[1])}  
    json_string = json.dumps(data5)
    print(data5)
except Exception as e:
    data5 = {'matchId': matchId , "accuracy" : 0 , "length"  :0, 'tier' : tier , 'championName' : championName, "key" : "unranked","rankingS" : int(new[0]+new[1])}  
    json_string = json.dumps(data5)
    print(json_string)
# Out:
# {'matchId': 'kr', 'accuracy': 0.9, 'length': 20, 'tier': 'GOLD', 'championName': 'Rumble', 'key': '승', 'rankingS': 0}
